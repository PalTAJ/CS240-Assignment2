# %% [markdown]
# # CS 240  Explotary Data Analysis

# %% [markdown]
# # Taj Saleh

# %% [markdown]
# # 214172235

# %%
import nsfg
import thinkstats2
import thinkplot

# %% [markdown]
# ### Read NSFG respondent data with .ReadFemResp() function that provided by nsfg.py and assign it a variable that called resp.

# %%
resp = nsfg.ReadFemResp()

# %%
resp.columns
# Out:
# Index([u'caseid', u'rscrinf', u'rdormres', u'rostscrn', u'rscreenhisp',
#        u'rscreenrace', u'age_a', u'age_r', u'cmbirth', u'agescrn',
#        ...
#        u'pubassis_i', u'basewgt', u'adj_mod_basewgt', u'finalwgt', u'secu_r',
#        u'sest', u'cmintvw', u'cmlstyr', u'screentime', u'intvlngth'],
#       dtype='object', length=3087)

# %%
resp.head(20)
# Out:
#     caseid  rscrinf  rdormres  rostscrn  rscreenhisp  rscreenrace  age_a  \
# 0     2298        1         5         5            1          5.0     27
# 1     5012        1         5         1            5          5.0     42
# 2    11586        1         5         1            5          5.0     43
# 3     6794        5         5         4            1          5.0     15
# 4      616        1         5         4            1          5.0     20
# 5      845        1         5         4            1          5.0     42
# 6    10333        5         5         3            1          5.0     17
# 7      855        5         5         4            5          5.0     22
# 8     8656        5         5         4            1          5.0     38
# 9     3566        5         5         4            5          5.0     21
# 10    5917        1         5         3            1          5.0     44
# 11    9200        5         5         3            1          5.0     26
# ...

# %%
resp.tail(30)
# Out:
#       caseid  rscrinf  rdormres  rostscrn  rscreenhisp  rscreenrace  age_a  \
# 7613    4640        5         5         6            5          5.0     18
# 7614    3998        5         5         2            5          5.0     24
# 7615    2432        5         5         5            5          5.0     15
# 7616    5438        1         5         3            5          5.0     30
# 7617    9643        1         5         2            5          5.0     24
# 7618    3030        1         5         1            5          5.0     34
# 7619   11585        1         5         4            5          5.0     34
# 7620    6677        1         5         4            1          5.0     26
# 7621   10744        5         5         8            5          1.0     22
# 7622    8403        5         5         4            5          5.0     19
# 7623    7574        5         5         4            5          5.0     19
# ...

# %%
print"There are ",len(resp)," rows and ", len(resp.columns)," columns"
# Out:
# There are  7643  rows and  3087  columns

# %%
resp["agescrn"].value_counts().sort_index()
# Out:
# 15    217
# 16    223
# 17    234
# 18    235
# 19    241
# 20    258
# 21    267
# 22    287
# 23    282
# 24    269
# 25    267
# 26    260
# 27    255
# 28    252
# 29    262
# 30    292
# 31    278
# 32    273
# 33    257
# 34    255
# 35    262
# 36    266
# 37    271
# 38    256
# 39    215
# 40    256
# 41    250
# 42    215
# 43    253
# 44    235
# Name: agescrn, dtype: int64

# %%
resp.agescrn.min()
# Out:
# 15

# %%
resp.agescrn.max()
# Out:
# 44

# %%
# temp = pres.agescrn
# for i in temp:
#     if i == 25 or i < 25:
#         print temp
#         print i 
resp[resp.agescrn <= 25 ].numpregs
# Out:
# 3       0.0
# 4       0.0
# 6       0.0
# 7       0.0
# 9       0.0
# 12      2.0
# 16      3.0
# 18      2.0
# 19      3.0
# 20      1.0
# 26      0.0
# 32      0.0
# 39      1.0
# 40      4.0
# 52      0.0
# 55      0.0
# 56      0.0
# 57      1.0
# 58      0.0
# 60      1.0
# 62      0.0
# 67      4.0
# 68      0.0
# 70      3.0
# 74      3.0
# 75      0.0
# 80      2.0
# 81      3.0
# 82      0.0
# 87      0.0
#        ...
# 7562    0.0
# 7567    0.0
# 7568    0.0
# 7575    1.0
# 7579    0.0
# 7580    1.0
# 7582    0.0
# 7587    0.0
# 7588    0.0
# 7589    2.0
# 7594    0.0
# 7595    0.0
# 7596    0.0
# 7597    2.0
# 7602    0.0
# 7610    0.0
# 7611    0.0
# 7613    0.0
# 7614    0.0
# 7615    0.0
# 7617    1.0
# 7621    0.0
# 7622    0.0
# 7623    0.0
# 7625    0.0
# 7626    0.0
# 7627    0.0
# 7628    0.0
# 7639    0.0
# 7641    0.0
# Name: numpregs, Length: 2780, dtype: float64

# %%
temp = resp[resp.agescrn <= 25 ].numpregs
temp.mean()
# Out:
# 0.709143268538517

# %%
resp.fmarno
# Out:
# 0       0
# 1       2
# 2       1
# 3       0
# 4       0
# 5       1
# 6       0
# 7       0
# 8       1
# 9       0
# 10      1
# 11      1
# 12      1
# 13      2
# 14      1
# 15      0
# 16      1
# 17      1
# 18      0
# 19      1
# 20      0
# 21      1
# 22      1
# 23      1
# 24      1
# 25      0
# 26      0
# 27      1
# 28      1
# 29      1
#        ..
# 7613    0
# 7614    1
# 7615    0
# 7616    2
# 7617    1
# 7618    1
# 7619    1
# 7620    1
# 7621    0
# 7622    0
# 7623    0
# 7624    1
# 7625    0
# 7626    0
# 7627    0
# 7628    0
# 7629    1
# 7630    1
# 7631    0
# 7632    1
# 7633    1
# 7634    1
# 7635    1
# 7636    1
# 7637    1
# 7638    2
# 7639    0
# 7640    0
# 7641    0
# 7642    0
# Name: fmarno, Length: 7643, dtype: int64

# %%
hist = thinkstats2.Hist(resp.fmarno)
hist
# Out:
# Hist({0L: 3517L, 1L: 3436L, 2L: 582L, 3L: 90L, 4L: 15L, 5L: 3L})

# %%
for val in sorted(hist.Values()):
    print val, hist[val]
# Out:
# 0 3517
# 1 3436
# 2 582
# 3 90
# 4 15
# 5 3

# %%
# %matplotlib inline
thinkplot.Hist(hist,width=0.5)
thinkplot.Config(xlabel='number of marriage ', ylabel='frequency')

# %%
neverMarried = resp[resp.fmarno == 0 ].fmarno

# %%
married = resp[resp.fmarno > 0 ].fmarno

# %%
neverMarried2 = resp[resp.fmarno == 0 ].totincr

# %%
married2 = resp[resp.fmarno > 0 ].totincr

# %%
width = 0.50

# thinkplot.PrePlot(2)
s2 = thinkstats2.Hist(neverMarried2, label='singles')
thinkplot.Hist(s2,align='right', width=width)
thinkplot.Config(xlabel='Salary', ylabel='income')

m2 = thinkstats2.Hist(married2, label='married')
thinkplot.Hist(m2,align='left', width=width)
thinkplot.Config(xlabel='Salary', ylabel='income')

# %%
print "singles mean"
neverMarried2.mean()
# Out:
# singles mean
# 8.020756326414558

# %%
print "signles min"
neverMarried2.min()
# Out:
# signles min
# 1

# %%
print "singles max"
neverMarried2.max()
# Out:
# singles max
# 14

# %%
print "single variance"
neverMarried2.var()
# Out:
# single variance
# 15.846838676954563

# %%
print "signles standard daviation"
neverMarried2.std()
# Out:
# signles standard daviation
# 3.9808087968344528

# %%
print "###################### MARRIED #########################"
print "married mean"
married2.mean()
# Out:
# ###################### MARRIED #########################
# married mean
# 9.495152690256907

# %%
print "married min"
married2.min()
# Out:
# married min
# 1

# %%
print "married max"
married2.max()
# Out:
# married max
# 14

# %%
print "variance"
married2.var()
# Out:
# variance
# 13.79864316455874

# %%
print "married standard daviation"
married2.std()
# Out:
# married standard daviation
# 3.71465249580075
